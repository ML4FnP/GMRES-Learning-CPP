# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
MLData=np.loadtxt("TimeData.txt")
DirectData= np.loadtxt("TimeDataDirect.txt")

# %%
plt.plot(DirectData,".r",label="Stokes Solver")
plt.plot(MLData,".b",label="ML Stokes Solver")
plt.ylim(0.09,0.12)
# plt.xlim(0,1000)
plt.title("Fixed Particle at Origin with Random Forcing")
plt.ylabel("Time-to-solution (s)")
plt.xlabel("i")
plt.legend()

# %%
plt.plot(DirectData,".r",label="Stokes Solver")
# plt.plot(MLData,".b",label="ML Stokes Solver")
plt.ylim(0.09,0.12)
# plt.xlim(0,1000)
plt.title("Fixed Particle at Origin with Random Forcing")
plt.ylabel("Time-to-solution (s)")
plt.xlabel("i")
plt.legend()

# %%
plt.plot(MLData,".b",label="ML Stokes Solver")
plt.ylim(0.09,0.12)
# plt.xlim(0,1000)
plt.title("Fixed Particle at Origin with Random Forcing")
plt.ylabel("Time-to-solution (s)")
plt.xlabel("i")
plt.legend()
