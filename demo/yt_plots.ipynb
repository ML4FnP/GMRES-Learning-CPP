# %%
 import yt

# %%
 print(yt.__version__)
# Out:
# 3.6.0

# %%
ds = yt.load("Test0000001")
# Out:
# yt : [INFO     ] 2020-08-21 14:07:23,133 Parameters: current_time              = 0.0
# yt : [INFO     ] 2020-08-21 14:07:23,133 Parameters: domain_dimensions         = [10 10 10]
# yt : [INFO     ] 2020-08-21 14:07:23,134 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-08-21 14:07:23,134 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
In [4]: ds.field_list
# Out:
# [('boxlib', 'presTest')]

# %%
slc = yt.SlicePlot(ds, "x", "presTest")
# Out:
# yt : [INFO     ] 2020-08-21 14:07:24,172 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-08-21 14:07:24,173 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-08-21 14:07:24,174 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-08-21 14:07:24,174 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-08-21 14:07:24,176 Making a fixed resolution buffer of (('boxlib', 'presTest')) 800 by 800

# %%
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc.save()
# Out:
# yt : [INFO     ] 2020-07-28 19:07:36,630 Saving plot plt0000001_Slice_z_pres.png
# ['plt0000001_Slice_z_pres.png']
