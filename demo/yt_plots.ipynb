# %%
 import yt

# %%
 print(yt.__version__)
# Out:
# 3.6.0

# %%
ds = yt.load("plt00000010")
# Out:
# yt : [INFO     ] 2020-10-20 19:01:49,585 Parameters: current_time              = 0.05
# yt : [INFO     ] 2020-10-20 19:01:49,585 Parameters: domain_dimensions         = [13 13 13]
# yt : [INFO     ] 2020-10-20 19:01:49,585 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-10-20 19:01:49,586 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
In [4]: ds.field_list
# Out:
# [('boxlib', ''),
#  ('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz')]

# %%
slc = yt.SlicePlot(ds, "x", "pres")
# Out:
# yt : [INFO     ] 2020-10-20 19:01:53,389 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-10-20 19:01:53,390 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-10-20 19:01:53,391 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-10-20 19:01:53,391 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-10-20 19:01:53,392 Making a fixed resolution buffer of (('boxlib', 'pres')) 800 by 800
# yt : [WARNING  ] 2020-10-20 19:01:53,409 Plot image for field ('boxlib', 'pres') has both positive and negative values. Min = -3.686075, Max = 3.686075.
# yt : [WARNING  ] 2020-10-20 19:01:53,409 Switching to symlog colorbar scaling unless linear scaling is specified later

# %%
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc.save()
# Out:
# yt : [INFO     ] 2020-07-28 19:07:36,630 Saving plot plt0000001_Slice_z_pres.png
# ['plt0000001_Slice_z_pres.png']
