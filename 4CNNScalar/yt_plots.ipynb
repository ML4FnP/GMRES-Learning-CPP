# %%
 import yt

# %%
 print(yt.__version__)
# Out:
# 3.6.0

# %%
ds = yt.load("plt0000010")
# Out:
# yt : [INFO     ] 2020-12-06 02:20:13,052 Parameters: current_time              = 0.09999999999999999
# yt : [INFO     ] 2020-12-06 02:20:13,052 Parameters: domain_dimensions         = [36 36 36]
# yt : [INFO     ] 2020-12-06 02:20:13,052 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-12-06 02:20:13,053 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
In [4]: ds.field_list
# Out:
# [('boxlib', ''),
#  ('boxlib', 'averaged_velx'),
#  ('boxlib', 'averaged_vely'),
#  ('boxlib', 'averaged_velz'),
#  ('boxlib', 'divergence'),
#  ('boxlib', 'pres'),
#  ('boxlib', 'shifted_velx'),
#  ('boxlib', 'shifted_vely'),
#  ('boxlib', 'shifted_velz')]

# %%
slc = yt.SlicePlot(ds, "z", "pres")
# Out:
# yt : [INFO     ] 2020-12-06 02:20:13,172 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-12-06 02:20:13,172 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-12-06 02:20:13,173 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-12-06 02:20:13,173 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-12-06 02:20:13,174 Making a fixed resolution buffer of (('boxlib', 'pres')) 800 by 800
# yt : [WARNING  ] 2020-12-06 02:20:13,188 Plot image for field ('boxlib', 'pres') has both positive and negative values. Min = -0.118822, Max = 0.174741.
# yt : [WARNING  ] 2020-12-06 02:20:13,189 Switching to symlog colorbar scaling unless linear scaling is specified later

# %%
slc.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
slc.save()
# Out:
# yt : [INFO     ] 2020-12-06 02:20:13,518 Saving plot plt0000010_Slice_z_pres.png
# ['plt0000010_Slice_z_pres.png']
